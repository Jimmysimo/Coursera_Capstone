# %% [markdown]
# # Segmenting & Clustering Pt 2

# %%
import pandas as pd
import numpy as np

link = "http://cocl.us/Geospatial_data"
df = pd.read_csv(link)
df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df.shape
# Out:
# (103, 3)

# %%
df.columns = ['Postcode','Latitude','Longitude']
df.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
url = 'https://raw.githubusercontent.com/Jimmysimo/Coursera_Capstone/main/SegmentingPt1.csv'
df2 = pd.read_csv(url)
df2.head()
# Out:
#    Unnamed: 0 Postcode                 Borough  \
# 0           0           Canadian postal codes
# 1           1     M1B             Scarborough
# 2           2     M1C             Scarborough
# 3           3     M1E             Scarborough
# 4           4     M1G             Scarborough
#
#                                        Neighbourhood
# 0                                                  ,
# 1                     Malvern, Rouge ,Malvern, Rouge
# 2  Rouge Hill, Port Union, Highland Creek ,Rouge ...
# 3  Guildwood, Morningside, West Hill ,Guildwood, ...
# 4                                     Woburn ,Woburn

# %%
df2.drop(['Unnamed: 0'],1, inplace = True)
df2.head()
# Out:
#   Postcode                 Borough  \
# 0           Canadian postal codes
# 1     M1B             Scarborough
# 2     M1C             Scarborough
# 3     M1E             Scarborough
# 4     M1G             Scarborough
#
#                                        Neighbourhood
# 0                                                  ,
# 1                     Malvern, Rouge ,Malvern, Rouge
# 2  Rouge Hill, Port Union, Highland Creek ,Rouge ...
# 3  Guildwood, Morningside, West Hill ,Guildwood, ...
# 4                                     Woburn ,Woburn

# %%
df3 = df.astype({'Postcode': 'object','Latitude': 'object', 'Longitude': 'object'})

# %%
df3['Postcode'] = df3['Postcode'].str.strip()
df2['Postcode'] = df2['Postcode'].str.strip()

# %%
df4 = pd.merge(df2,df3,how='inner',on='Postcode')
df4.head(10)
# Out:
#   Postcode       Borough                                      Neighbourhood  \
# 0      M1B  Scarborough                      Malvern, Rouge ,Malvern, Rouge
# 1      M1C  Scarborough   Rouge Hill, Port Union, Highland Creek ,Rouge ...
# 2      M1E  Scarborough   Guildwood, Morningside, West Hill ,Guildwood, ...
# 3      M1G  Scarborough                                      Woburn ,Woburn
# 4      M1H  Scarborough                                Cedarbrae ,Cedarbrae
# 5      M1J  Scarborough            Scarborough Village ,Scarborough Village
# 6      M1K  Scarborough   Kennedy Park, Ionview, East Birchmount Park ,K...
# 7      M1L  Scarborough   Golden Mile, Clairlea, Oakridge ,Golden Mile, ...
# 8      M1M  Scarborough   Cliffside, Cliffcrest, Scarborough Village Wes...
# 9      M1N  Scarborough   Birch Cliff, Cliffside West ,Birch Cliff, Clif...
#
#   Latitude Longitude
# 0  43.8067  -79.1944
# 1  43.7845  -79.1605
# 2  43.7636  -79.1887
# 3   43.771  -79.2169
# ...

# %%
df4.to_csv('Segmenting2.csv')
